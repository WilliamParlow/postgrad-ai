# %% [markdown]
# ## Análise Exploratória dos Dados
# * Base de Dados: Air Quality Dataset
# * https://www.kaggle.com/datasets/citrahsagala/airquality

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('AirQualityUCI.csv')

# %%
df
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/3/2004  18.00.00     2.6         1360       150      11.9
# 1     10/3/2004  19.00.00     2.0         1292       112       9.4
# 2     10/3/2004  20.00.00     2.2         1402        88       9.0
# 3     10/3/2004  21.00.00     2.2         1376        80       9.2
# 4     10/3/2004  22.00.00     1.6         1272        51       6.5
# ...         ...       ...     ...          ...       ...       ...
# 9352   4/4/2005  10.00.00     3.1         1314      -200      13.5
# 9353   4/4/2005  11.00.00     2.4         1163      -200      11.4
# 9354   4/4/2005  12.00.00     2.4         1142      -200      12.4
# 9355   4/4/2005  13.00.00     2.1         1003      -200       9.5
# 9356   4/4/2005  14.00.00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# 1               955      103          1174       92          1559
# 2               939      131          1140      114          1555
# 3               948      172          1092      122          1584
# 4               836      131          1205      116          1490
# ...             ...      ...           ...      ...           ...
# 9352           1101      472           539      190          1374
# 9353           1027      353           604      179          1264
# 9354           1063      293           603      175          1241
# 9355            961      235           702      156          1041
# 9356           1047      265           654      168          1129
#
#       PT08.S5(O3)     T    RH      AH
# 0            1268  13.6  48.9  0.7578
# 1             972  13.3  47.7  0.7255
# 2            1074  11.9  54.0  0.7502
# 3            1203  11.0  60.0  0.7867
# 4            1110  11.2  59.6  0.7888
# ...           ...   ...   ...     ...
# 9352         1729  21.9  29.3  0.7568
# 9353         1269  24.3  23.7  0.7119
# 9354         1092  26.9  18.3  0.6406
# 9355          770  28.3  13.5  0.5139
# 9356          816  28.5  13.1  0.5028
#
# [9357 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   str
#  1   Time           9357 non-null   str
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   int64
#  4   NMHC(GT)       9357 non-null   int64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   int64
#  7   NOx(GT)        9357 non-null   int64
#  8   PT08.S3(NOx)   9357 non-null   int64
#  9   NO2(GT)        9357 non-null   int64
#  10  PT08.S4(NO2)   9357 non-null   int64
#  11  PT08.S5(O3)    9357 non-null   int64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
# dtypes: float64(5), int64(8), str(2)
# memory usage: 1.1 MB

# %% [markdown]
# # Visualização dos Dados

# %% [markdown]
# #### (1) `Box Plot`
# * Resumo das propriedades de um conjunto de valores;
# * Ex: mínimo, primeiro quartil, mediana, terceiro quartil e máximo

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH'],
#       dtype='str')

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data = df[['T']])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 3))

def create_boxplot(feature):
    sns.boxplot(data = df[[feature]])
    plt.title(feature, fontsize = 10)

plt.subplot(1,3,1)
create_boxplot('CO(GT)')

plt.subplot(1,3,2)
create_boxplot('T')

plt.subplot(1,3,3)
create_boxplot('RH')

plt.show()

# %% [markdown]
# #### Tratando outliers

# %%
df.shape
# Out:
# (9357, 15)

# %%
df['T'].loc[df['T']<=-100].size
# Out:
# 366

# %%
# Antes da substituição
print(df['T'].mean())
print(df['RH'].mean())
print(df['CO(GT)'].mean())
# Out:
# 9.778305012290263
# 39.48537992946457
# -34.20752377898899

# %%
# Calcular a média sem o outlier
mediaT = df['T'].loc[df['T'] >=0].mean()
mediaCO = df['CO(GT)'].loc[df['CO(GT)']>=0].mean()
mediaRH = df['RH'].loc[df['RH'] >=0].mean()

# %%
print(mediaT)
print(mediaCO)
print(mediaRH)
# Out:
# 18.345533526397862
# 2.1527495439145166
# 49.2342008675342

# %%
# Substui o outlier pela média
# linha/coluna
# Método de atribuição por coluna mais eficiente, aplicando o valor apenas onde a condição é atendida
df.loc[df['T']<0,'T'] = mediaT
df.loc[df['CO(GT)']<0,'CO(GT)'] = mediaCO
df.loc[df['RH']<0,'RH'] = mediaRH

# %%
#  Após a substituição
print(df['T'].mean())
print(df['RH'].mean())
print(df['CO(GT)'].mean())
# Out:
# 18.345533526397862
# 49.2342008675342
# 2.152749543914517

# %%
# Plotando novamente os gráficos

plt.subplot(1,3,1)
create_boxplot('CO(GT)')

plt.subplot(1,3,2)
create_boxplot('T')

plt.subplot(1,3,3)
create_boxplot('RH')

plt.show()

# %% [markdown]
# #### (2) `Violin Plot`
# -  ViolinPlot combina a visualização do boxplot juntamente com um plot de densidade (similar ao que vemos nos histogramas);
# - Dentro do ViolinPlot encontramos os mesmos elementos que encontramos no BoxPlot;
# - Mais detalhes: https://towardsdatascience.com/violin-plots-explained-fb1d115e023d
# <span style="width:80%;text-align: center;"><img align = left src="https://miro.medium.com/v2/resize:fit:1040/format:webp/1*TTMOaNG1o4PgQd-e8LurMg.png" style="height:550px;"></span>

# %%
plt.figure(figsize=(10, 3))

def create_violinplot(feature):
    sns.violinplot(data = df[[feature]])
    plt.title(feature, fontsize = 10)

plt.subplot(1,3,1)
create_violinplot('CO(GT)')

plt.subplot(1,3,2)
create_violinplot('T')

plt.subplot(1,3,3)
create_violinplot('RH')

plt.show()

# %% [markdown]
# #### (3) `Heatmap`
# * Avaliando correlações

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH'],
#       dtype='str')

# %%
plt.figure(figsize = (13,10))
sns.heatmap(df[['CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
       'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
       'PT08.S5(O3)', 'T', 'RH', 'AH']].corr(), cmap= 'Blues', annot= True)
plt.title("Gráfico de Correlação", size = 20)
plt.show()

# %% [markdown]
# #### (4) `Histplot`
# * Frequência dos dados

# %%
plt.figure(figsize=(15, 6))

def create_histogram(feature):
    sns.histplot(data = df[[feature]], kde=False)
    plt.title(feature, fontsize = 10)

plt.subplot(1,3,1)
create_histogram('CO(GT)')

plt.subplot(1,3,2)
create_histogram('T')

plt.subplot(1,3,3)
create_histogram('RH')

plt.show()

# %% [markdown]
# # Códigos feitos por mim

# %% [markdown]
# ### Teste de remoção do excesso de amostras concentradas em "T"

# %%
df.shape
# Out:
# (9357, 15)

# %%
# Remoção de valores extremos na coluna 'T'
excessiveDf = df['T'].loc[df['T']>=-5].loc[df['T']<=10]
excessiveDf = excessiveDf.sample(n=len(excessiveDf) // 2)
df.drop(excessiveDf.index, inplace=True)

# %%
df.shape
# Out:
# (8516, 15)

# %%
plt.figure(figsize=(15, 6))

def create_histogram(feature):
    sns.histplot(data = df[[feature]], kde=False)
    plt.title(feature, fontsize = 10)

plt.subplot(1,3,1)
create_histogram('CO(GT)')

plt.subplot(1,3,2)
create_histogram('T')

plt.subplot(1,3,3)
create_histogram('RH')

plt.show()

# %% [markdown]
# # Perguntas de interesse:
# * Concentração de dióxido de Carbono (CO(GT))
# * Temperatura média (T)
# * Umidade Relativa (RH)

# %%
df = pd.read_csv('AirQualityUCI_preprocessed.csv')
df
# Out:
#             Date  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 0     2004-03-10     2.6         1360       150      11.9           1046
# 1     2004-03-10     2.0         1292       112       9.4            955
# 2     2004-03-10     2.2         1402        88       9.0            939
# 3     2004-03-10     2.2         1376        80       9.2            948
# 4     2004-03-10     1.6         1272        51       6.5            836
# ...          ...     ...          ...       ...       ...            ...
# 9352  2005-04-04     3.1         1314      -200      13.5           1101
# 9353  2005-04-04     2.4         1163      -200      11.4           1027
# 9354  2005-04-04     2.4         1142      -200      12.4           1063
# 9355  2005-04-04     2.1         1003      -200       9.5            961
# 9356  2005-04-04     2.2         1071      -200      11.9           1047
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0         166          1056      113          1692         1268  13.6  48.9
# 1         103          1174       92          1559          972  13.3  47.7
# 2         131          1140      114          1555         1074  11.9  54.0
# 3         172          1092      122          1584         1203  11.0  60.0
# 4         131          1205      116          1490         1110  11.2  59.6
# ...       ...           ...      ...           ...          ...   ...   ...
# 9352      472           539      190          1374         1729  21.9  29.3
# 9353      353           604      179          1264         1269  24.3  23.7
# 9354      293           603      175          1241         1092  26.9  18.3
# 9355      235           702      156          1041          770  28.3  13.5
# 9356      265           654      168          1129          816  28.5  13.1
#
#           AH  Hour  month  year  day
# 0     0.7578    18      3  2004   10
# 1     0.7255    19      3  2004   10
# 2     0.7502    20      3  2004   10
# 3     0.7867    21      3  2004   10
# 4     0.7888    22      3  2004   10
# ...      ...   ...    ...   ...  ...
# 9352  0.7568    10      4  2005    4
# 9353  0.7119    11      4  2005    4
# 9354  0.6406    12      4  2005    4
# 9355  0.5139    13      4  2005    4
# 9356  0.5028    14      4  2005    4
#
# [9357 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   str
#  1   CO(GT)         9357 non-null   float64
#  2   PT08.S1(CO)    9357 non-null   int64
#  3   NMHC(GT)       9357 non-null   int64
#  4   C6H6(GT)       9357 non-null   float64
#  5   PT08.S2(NMHC)  9357 non-null   int64
#  6   NOx(GT)        9357 non-null   int64
#  7   PT08.S3(NOx)   9357 non-null   int64
#  8   NO2(GT)        9357 non-null   int64
#  9   PT08.S4(NO2)   9357 non-null   int64
#  10  PT08.S5(O3)    9357 non-null   int64
#  11  T              9357 non-null   float64
#  12  RH             9357 non-null   float64
#  13  AH             9357 non-null   float64
#  14  Hour           9357 non-null   int64
#  15  month          9357 non-null   int64
#  16  year           9357 non-null   int64
#  17  day            9357 non-null   int64
# dtypes: float64(5), int64(12), str(1)
# memory usage: 1.3 MB

# %%
# Concentração de CO(GT) por mês
df.groupby('month')['CO(GT)'].agg(['min','max','mean','std'])
# Out:
#        min   max      mean       std
# month
# 1      0.1   8.7  2.136676  1.347566
# 2      0.3   8.4  2.096986  1.306472
# 3      0.1   8.1  2.144342  1.353374
# 4      0.3   7.3  2.145693  1.187923
# 5      0.1   6.5  1.983492  1.077254
# 6      0.1   6.4  1.926679  1.081146
# 7      0.1   5.3  1.876897  0.964013
# 8      0.1   3.5  1.593258  0.626322
# 9      0.2   7.5  2.161599  1.253465
# 10     0.4   9.5  2.454859  1.220737
# 11     0.1  11.9  2.655087  1.875342
# 12     0.2   9.9  2.667589  1.653303

# %%
# Concentração de CO(GT) por hora
df.groupby('Hour')['CO(GT)'].agg(['min','max','mean','std'])
# Out:
#       min   max      mean       std
# Hour
# 0     0.1   5.9  1.843379  0.819362
# 1     0.1   5.6  1.585472  0.767023
# 2     0.1   5.5  1.288186  0.754929
# 3     0.1   5.2  1.141319  0.743299
# 4     0.1   2.8  1.512898  0.769884
# 5     0.1   2.9  0.982438  0.662868
# 6     0.1   3.5  1.142545  0.616991
# 7     0.1   5.7  1.871384  1.071947
# 8     0.1   7.3  2.703314  1.389290
# 9     0.1   8.1  2.840060  1.452900
# 10    0.2   6.6  2.499034  1.178935
# 11    0.1   6.6  2.242894  0.982504
# 12    0.1   6.0  2.166861  0.903925
# 13    0.1   6.9  2.193272  1.022077
# 14    0.1   7.9  2.130451  1.109003
# 15    0.1   6.1  2.066262  0.992089
# 16    0.2   7.1  2.249781  1.096421
# 17    0.3   8.4  2.717377  1.459189
# 18    0.1  10.2  3.248735  1.809442
# 19    0.4  11.9  3.506292  1.776177
# 20    0.7  11.5  3.276684  1.675255
# 21    0.3   8.6  2.534255  1.246162
# 22    0.1   5.4  2.004013  0.812077
# 23    0.1   5.4  1.920558  0.787714

# %%
# Temperatura por mês
df.groupby('month')['T'].agg(['min','max','mean','std'])
# Out:
#              min        max       mean       std
# month
# 1       1.000000  18.345534   9.052658  4.622699
# 2       0.300000  19.900000   8.383870  4.839864
# 3       0.000000  29.300000  13.898196  5.532694
# 4       7.400000  31.300000  16.837335  4.796348
# 5       7.400000  32.800000  20.244808  5.169908
# 6      16.500000  42.200000  26.047403  6.077251
# 7      16.200000  44.600000  29.404228  6.182791
# 8      18.345534  40.500000  28.420069  5.690807
# 9      11.900000  40.700000  24.463499  5.488851
# 10     12.600000  30.800000  20.494685  3.587529
# 11      1.300000  26.800000  13.485417  4.990447
# 12      1.200000  20.300000  11.915514  4.082517

# %%
df.groupby('month')['RH'].agg(['min','max','mean','std'])
# Out:
#         min   max       mean        std
# month
# 1      17.2  86.6  55.965170  13.913074
# 2      18.0  86.6  51.761308  16.276071
# 3      13.5  84.0  50.606806  15.689702
# 4       9.9  82.4  49.017749  16.214684
# 5       9.2  85.2  43.649434  16.687512
# 6      11.9  82.3  40.345972  13.940616
# 7       9.6  69.3  33.075987  12.713244
# 8      10.0  81.8  43.391097  14.213799
# 9      13.8  87.2  44.122938  14.961395
# 10     31.8  86.5  61.893863  11.245373
# 11     14.0  87.1  59.274861  16.008765
# 12     16.3  88.7  56.899511  16.547481
