# %% [markdown]
# # Considere a base de dados Airline Passenger Satisfaction
#
# https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction
#
# Utilizando a biblioteca Pipeline, faça um comparativo entre as abordagens filtro e Wrapper:
# Filter: Mutual Information e ANOVA;
# Wrapper: SFS (Forward e Backward) e RFE
# Avalie o desempenho de cada abordagem com 10 e 15 features, respectivamente.
# Verifique as diferenças entre as features com o diagrama de Venn.
