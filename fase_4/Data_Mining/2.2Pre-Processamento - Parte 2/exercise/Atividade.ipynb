# %% [markdown]
# # Considere a base de dados Hotel Reservations Dataset
#
# https://www.kaggle.com/datasets/ahsan81/hotel-reservations-classification-dataset
#
# Avalie as diferenças nos resultados comparando as abordagens de transformação Label Encoder, get_dummies e One Hot Encoder.
#
# Verifque também se ocorre melhora nos resultados a partir da aplicação da técnica de balanceamento com SMOTE e amostragem por validação cruzada (KFold).
