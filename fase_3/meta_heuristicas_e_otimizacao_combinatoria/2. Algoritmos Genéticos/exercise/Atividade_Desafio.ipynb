# %% [markdown]
# ### Considere o problema One Max armadilha (deceptive):
#
# * Faça uma versão do Algoritmo Genético Puro (sem framework)
# * Desenvolver o operador de cruzamento com mais de 1 ponto de corte
# * Desenvolver o método de seleção por roleta
# * Comparar os resultados com o framework Mlrose
