# %% [markdown]
# #### Avaliar os framewroks EasyGA e DEAP para todas as bases  do tipo Low-dimensional 0/1 knapsack problems.
#
# link: http://artemisa.unicauca.edu.co/~johnyortega/instances_01_KP/
#
# Estas bases já estão disponíveis no bloco de repositório de código fonte.
#
# Avalie diferenes operadores de cruzamento, mutação e seleção de cada framework.
#
# Identifique a configuração de qual framework apresentou melhores resultados.
