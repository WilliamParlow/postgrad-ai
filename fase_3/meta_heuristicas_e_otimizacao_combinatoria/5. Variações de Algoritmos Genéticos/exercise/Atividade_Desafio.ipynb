# %% [markdown]
# # A partir do framework DEAP, desenvolver as técnicas AG baseado em Ilhas e
# Estratégias Evolutivas (Mu Puls Lambda e Mu Comma Lambda) para o problema Knapsack.
#
# Além disso, faça diversos testes ajustando os parâmetros das 3 abordagens.
#
# Apresente um comparativo indicando qual abordagem apresentou os melhores resultados.
