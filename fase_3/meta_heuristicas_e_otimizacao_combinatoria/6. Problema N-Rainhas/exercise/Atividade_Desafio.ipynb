# %% [markdown]
# #### A partir do framework DEAP, desenvolver as técnicas AG baseado em Ilhas e Estratégias Evolutivas (Mu Puls Lambda e Mu Comma Lambda) para os problemas 20, 30 e 50-Rainhas.
#
# Além disso, faça diversos testes ajustando os parâmetros das 3 abordagens.
#
# Pede-se:
# - Faça 20 rodadas para cada algoritmo, apresentando o melhor fitness de cada rodada;
# - Apresente um comparativo entre AG baseado em Ilhas e
# Estratégias Evolutivas (Mu Puls Lambda e Mu Comma Lambda) destacando com qual frequência cada abordagem obteve o melhor fitness em cada rodada.
