# %% [markdown]
# # Problema OneMax
#
# * Busca-se maximizar o número de "1s" durante a busca;
# * Inicialmente as soluções são geradas aleatoriamente por uma lista de bits 0 e 1;
# * O objetivo é gerar a solução com a maior quantidade de “1”
#     * Exemplo:
#     * 10010 (soma == 2)
#     * 01110 (soma == 3)
#     * 11111 (soma == 5)

# %% [markdown]
# #### Instalação do framework

# %%
# !pip install mlrose
# !pip install https://github.com/gkhayes/mlrose/archive/refs/heads/master.zip
# Out:
# ...
#      \ 218.4 kB 4.7 MB/s 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mlrose: filename=mlrose-1.3.0-py3-none-any.whl size=27711 sha256=6657b178bb351b51f4a00533001b5dba11129197aba492248c37c76fb42f1777
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pxpbbv92/wheels/e1/d4/4c/90cb7cdd2dab1e4aa18364e040225ad5941d9c830aad84a6ec
# Successfully built mlrose
# ...

# %%
# Configurações para execução do framework
import six
import sys
sys.modules['sklearn.externals.six'] = six
import mlrose

# %% [markdown]
# ### Construção da função fitness

# %%
# objective function
def fitness_function(individual):
    """The sum of all ones in the individual (list)."""
    count = 0
    for bit in individual:
        count += bit

    return count

# %% [markdown]
# ### Construção do problema no mlrose

# %%
fitness = mlrose.CustomFitness(fitness_function)

# %%
problema = mlrose.DiscreteOpt(length = 5, fitness_fn = fitness,
                             maximize = True, max_val = 2)

# %% [markdown]
# ### Algoritmo Genético

# %%
solucao_GA, melhor_custo = mlrose.genetic_alg(problema, pop_size=10, mutation_prob=0.2,
                                       max_iters=10)
solucao_GA, melhor_custo
# Out:
# (array([1, 1, 1, 1, 1]), 5.0)
