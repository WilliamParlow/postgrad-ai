# %% [markdown]
# ### Considere o problema Quebra de Senha (PasswordCrack):
#
# - Faça uma versão do Algoritmo Genético com framework DEAP
# - Faça teste com operadores de cruzamento SinglePoint e MultPoint
# - Façar testes com os métodos de seleção por roleta e torneio
# - Comparar os resultados com o framework EasyGA
